# %% [markdown]
# ### 1. Data Exploration

# %%
import numpy as np
import pandas as pd 
df =pd.read_csv("Titanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
numerical_col =df.select_dtypes(include =['int64','float64']).columns
numerical_col
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
categorical_col =df.select_dtypes(include =["object"]).columns
categorical_col
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
#summary statistics---> Mean ,Median, Mode,Standard deviation,Minimum,Maximum
a1 =df["Age"].mean()
a2 =df["Age"].median()
a3 =df["Age"].mode()
a4 =df["Age"].std()
a5 =df["Age"].min()
a6 =df["Age"].max()
print("Mean of the age:", a1)
print("Median of the age:",a2)
print("Mode of the age:", a3)
print("Standard deviation of the age:", a4)
print("Minimum value of the age:", a5)
print("Maximum value of the age:", a6)
# Out:
# Mean of the age: 29.69911764705882
# Median of the age: 28.0
# Mode of the age: 0    24.0
# Name: Age, dtype: float64
# Standard deviation of the age: 14.526497332334044
# Minimum value of the age: 0.42
# Maximum value of the age: 80.0

# %%
a1 =df["SibSp"].mean()
a2 =df["SibSp"].median()
a3 =df["SibSp"].mode()
a4 =df["SibSp"].std()
a5 =df["SibSp"].min()
a6 =df["SibSp"].max()
print("Mean of the SibSp:", a1)
print("Median of the SibSp:",a2)
print("Mode of the SibSp:", a3)
print("Standard deviation of the SibSp:", a4)
print("Minimum value of the SibSp:", a5)
print("Maximum value of the SibSp:", a6)
# Out:
# Mean of the SibSp: 0.5230078563411896
# Median of the SibSp: 0.0
# Mode of the SibSp: 0    0
# Name: SibSp, dtype: int64
# Standard deviation of the SibSp: 1.1027434322934275
# Minimum value of the SibSp: 0
# Maximum value of the SibSp: 8

# %%
a1 =df["Parch"].mean()
a2 =df["Parch"].median()
a3 =df["Parch"].mode()
a4 =df["Parch"].std()
a5 =df["Parch"].min()
a6 =df["Parch"].max()
print("Mean of the Parch:", a1)
print("Median of the Parch:",a2)
print("Mode of the Parch:", a3)
print("Standard deviation of the Parch:", a4)
print("Minimum value of the Parch:", a5)
print("Maximum value of the Parch:", a6)
# Out:
# Mean of the Parch: 0.38159371492704824
# Median of the Parch: 0.0
# Mode of the Parch: 0    0
# Name: Parch, dtype: int64
# Standard deviation of the Parch: 0.8060572211299559
# Minimum value of the Parch: 0
# Maximum value of the Parch: 6

# %%
a1 =df["Fare"].mean()
a2 =df["Fare"].median()
a3 =df["Fare"].mode()
a4 =df["Fare"].std()
a5 =df["Fare"].min()
a6 =df["Fare"].max()
print("Mean of the Fare:", a1)
print("Median of the Fare:",a2)
print("Mode of the Fare:", a3)
print("Standard deviation of the Fare:", a4)
print("Minimum value of the Fare:", a5)
print("Maximum value of the Fare:", a6)
# Out:
# Mean of the Fare: 32.204207968574636
# Median of the Fare: 14.4542
# Mode of the Fare: 0    8.05
# Name: Fare, dtype: float64
# Standard deviation of the Fare: 49.693428597180905
# Minimum value of the Fare: 0.0
# Maximum value of the Fare: 512.3292

# %% [markdown]
# ### Histograms

# %%
#EDA 
#histograms
import matplotlib.pyplot as plt 
print(df["Pclass"])
df["Pclass"].hist()
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# <Axes: >

# %%
print(df["Sex"])
df["Sex"].hist()
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object
# <Axes: >

# %%
print(df["Age"])
df["Age"].hist()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
# <Axes: >

# %%
print(df["SibSp"])
df["SibSp"].hist()
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64
# <Axes: >

# %%
print(df["Parch"])
df["Parch"].hist()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64
# <Axes: >

# %%
print(df["Ticket"])
df["Ticket"].hist()
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object
# <Axes: >

# %%
print(df["Fare"])
df["Fare"].hist()
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64
# <Axes: >

# %%
print(df["Cabin"])
df["Cabin"].hist()
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object
# <Axes: >

# %%
print(df["Embarked"])
df["Embarked"].hist()
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object
# <Axes: >

# %% [markdown]
# ### Box plots

# %%
#box plots 
df.boxplot(column =["Pclass"], vert =False)
# Out:
# <Axes: >

# %%
#box plots 
df.boxplot(column =["Age"], vert =False)
# Out:
# <Axes: >

# %%
df.boxplot(column =["SibSp"], vert =False)
# Out:
# <Axes: >

# %%
df.boxplot(column =["Parch"], vert =False)
# Out:
# <Axes: >

# %%
df.boxplot(column =["Fare"], vert =False)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt 
plt.scatter(x =df["Pclass"], y =df["Survived"], color ='red')
plt.plot(df["Pclass"], df["Survived"],c ='black')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(x =df["Sex"], y =df["Survived"], color ='blue')
plt.plot(df["Sex"], df["Survived"],c ='pink')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(x =df["Age"], y =df["Survived"], color ='red')
plt.plot(df["Age"], df["Survived"],c ='yellow')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(x =df["SibSp"], y =df["Survived"], color ='orange')
plt.plot(df["SibSp"], df["Survived"],c ='green')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(x =df["Parch"], y =df["Survived"], color ='black')
plt.plot(df["Parch"], df["Survived"],c ='teal')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(x =df["Ticket"], y =df["Survived"], color ='blue')
plt.plot(df["Ticket"], df["Survived"],c ='grey')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(x =df["Fare"], y =df["Survived"], color ='red')
plt.plot(df["Fare"], df["Survived"],c ='purple')
plt.show()

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %% [markdown]
# ### 2. Data Preprocessing

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Name"] =LE.fit_transform(df["Name"])
print(df["Name"])
# Out:
# 0      108
# 1      190
# 2      353
# 3      272
# 4       15
#       ...
# 886    548
# 887    303
# 888    413
# 889     81
# 890    220
# Name: Name, Length: 891, dtype: int32

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Sex"] =LE.fit_transform(df["Sex"])
print(df["Sex"])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int32

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Ticket"] =LE.fit_transform(df["Ticket"])
print(df["Ticket"])
# Out:
# 0      523
# 1      596
# 2      669
# 3       49
# 4      472
#       ...
# 886    101
# 887     14
# 888    675
# 889      8
# 890    466
# Name: Ticket, Length: 891, dtype: int32

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Cabin"] =LE.fit_transform(df["Cabin"])
print(df["Cabin"])
# Out:
# 0      147
# 1       81
# 2      147
# 3       55
# 4      147
#       ...
# 886    147
# 887     30
# 888    147
# 889     60
# 890    147
# Name: Cabin, Length: 891, dtype: int32

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Embarked"] =LE.fit_transform(df["Embarked"])
print(df["Embarked"])
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: Embarked, Length: 891, dtype: int32

# %%
'''
# Fill missing with median/mean
df['Age'].fillna(df['Age'].median(), inplace=True)

# Fill missing with mean/medain
df['Cabin'].fillna(df['Cabin'].median(), inplace=True)

# Fill missing with median/mean
df['Embarked'].fillna(df['Embarked'].median(), inplace=True)
'''
# Out:
# "\n# Fill missing with median/mean\ndf['Age'].fillna(df['Age'].median(), inplace=True)\n\n# Fill missing with mean/medain\ndf['Cabin'].fillna(df['Cabin'].median(), inplace=True)\n\n# Fill missing with median/mean\ndf['Embarked'].fillna(df['Embarked'].median(), inplace=True)\n"

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.038559  0.042939  0.036847
# Survived       -0.005007  1.000000 -0.338481 -0.057343 -0.543351 -0.077221
# Pclass         -0.035144 -0.338481  1.000000  0.052831  0.131900 -0.369226
# Name           -0.038559 -0.057343  0.052831  1.000000  0.020314  0.062583
# Sex             0.042939 -0.543351  0.131900  0.020314  1.000000  0.093254
# Age             0.036847 -0.077221 -0.369226  0.062583  0.093254  1.000000
# SibSp          -0.057527 -0.035322  0.083081 -0.017230 -0.114631 -0.308247
# Parch          -0.001652  0.081629  0.018443 -0.049105 -0.245489 -0.189119
# Ticket         -0.056554 -0.164549  0.319869  0.047348  0.059372 -0.075934
# Fare            0.012658  0.257307 -0.549500 -0.049173 -0.182333  0.096067
# Cabin          -0.035077 -0.254888  0.684121  0.061959  0.096681 -0.252331
# Embarked        0.013083 -0.163517  0.157112 -0.004557  0.104057 -0.025252
#
#                 SibSp     Parch    Ticket      Fare     Cabin  Embarked
# PassengerId -0.057527 -0.001652 -0.056554  0.012658 -0.035077  0.013083
# Survived    -0.035322  0.081629 -0.164549  0.257307 -0.254888 -0.163517
# Pclass       0.083081  0.018443  0.319869 -0.549500  0.684121  0.157112
# Name        -0.017230 -0.049105  0.047348 -0.049173  0.061959 -0.004557
# Sex         -0.114631 -0.245489  0.059372 -0.182333  0.096681  0.104057
# Age         -0.308247 -0.189119 -0.075934  0.096067 -0.252331 -0.025252
# SibSp        1.000000  0.414838  0.079461  0.159651  0.043593  0.066654
# Parch        0.414838  1.000000  0.020003  0.216225 -0.028324  0.038322
# Ticket       0.079461  0.020003  1.000000 -0.013885  0.243696 -0.006041
# Fare         0.159651  0.216225 -0.013885  1.000000 -0.503355 -0.221226
# Cabin        0.043593 -0.028324  0.243696 -0.503355  1.000000  0.193205
# Embarked     0.066654  0.038322 -0.006041 -0.221226  0.193205  1.000000

# %% [markdown]
# ### 3.Model Building

# %%
#Data partition 
Y =df["Survived"]
X =df.iloc[:, 8:]
X.head()
# Out:
#    Ticket     Fare  Cabin  Embarked
# 0     523   7.2500    147         2
# 1     596  71.2833     81         0
# 2     669   7.9250    147         2
# 3      49  53.1000     55         2
# 4     472   8.0500    147         2

# %%
from sklearn.linear_model import LogisticRegression 
model =LogisticRegression()
model.fit(X, Y)
# Out:
# LogisticRegression()

# %%
df["Y_pred"] =model.predict(X)

# %% [markdown]
# ### 4. Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score 
score =accuracy_score(Y, df["Y_pred"])
print("accuracy score:", np.round(score, 2))

ps=precision_score(Y, df["Y_pred"])
print("precision score:", np.round(ps, 2))

rs =recall_score(Y, df["Y_pred"])
print("recall score:", np.round(rs, 2))

f1s =f1_score(Y, df["Y_pred"])
print("F1 score:", np.round(f1s, 2))
# Out:
# accuracy score: 0.69
# precision score: 0.72
# recall score: 0.34
# F1 score: 0.46

# %%
from sklearn.metrics import roc_auc_score
auc =roc_auc_score(Y, df["Y_pred"])
print("Area under curve:",  np.round(auc, 3))
print("Area under curve:", (auc * 100).round(3))
# Out:
# Area under curve: 0.628
# Area under curve: 62.77

# %%
from sklearn.metrics import roc_curve 

fpr,tpr,dummy =roc_curve(Y, df["Y_pred"])

import matplotlib.pyplot as plt 
plt.scatter(x =fpr, y =tpr)
plt.plot(fpr,tpr, color ="red")
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %% [markdown]
# ### 5. Interpretation

# %%
model.intercept_
# Out:
# array([0.82462631])

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.038559  0.042939  0.036847
# Survived       -0.005007  1.000000 -0.338481 -0.057343 -0.543351 -0.077221
# Pclass         -0.035144 -0.338481  1.000000  0.052831  0.131900 -0.369226
# Name           -0.038559 -0.057343  0.052831  1.000000  0.020314  0.062583
# Sex             0.042939 -0.543351  0.131900  0.020314  1.000000  0.093254
# Age             0.036847 -0.077221 -0.369226  0.062583  0.093254  1.000000
# SibSp          -0.057527 -0.035322  0.083081 -0.017230 -0.114631 -0.308247
# Parch          -0.001652  0.081629  0.018443 -0.049105 -0.245489 -0.189119
# Ticket         -0.056554 -0.164549  0.319869  0.047348  0.059372 -0.075934
# Fare            0.012658  0.257307 -0.549500 -0.049173 -0.182333  0.096067
# Cabin          -0.035077 -0.254888  0.684121  0.061959  0.096681 -0.252331
# Embarked        0.013083 -0.163517  0.157112 -0.004557  0.104057 -0.025252
# Y_pred          0.011110  0.322023 -0.724340 -0.046634 -0.170000  0.224708
#
#                 SibSp     Parch    Ticket      Fare     Cabin  Embarked  \
# PassengerId -0.057527 -0.001652 -0.056554  0.012658 -0.035077  0.013083
# Survived    -0.035322  0.081629 -0.164549  0.257307 -0.254888 -0.163517
# Pclass       0.083081  0.018443  0.319869 -0.549500  0.684121  0.157112
# Name        -0.017230 -0.049105  0.047348 -0.049173  0.061959 -0.004557
# Sex         -0.114631 -0.245489  0.059372 -0.182333  0.096681  0.104057
# Age         -0.308247 -0.189119 -0.075934  0.096067 -0.252331 -0.025252
# SibSp        1.000000  0.414838  0.079461  0.159651  0.043593  0.066654
# Parch        0.414838  1.000000  0.020003  0.216225 -0.028324  0.038322
# Ticket       0.079461  0.020003  1.000000 -0.013885  0.243696 -0.006041
# Fare         0.159651  0.216225 -0.013885  1.000000 -0.503355 -0.221226
# Cabin        0.043593 -0.028324  0.243696 -0.503355  1.000000  0.193205
# Embarked     0.066654  0.038322 -0.006041 -0.221226  0.193205  1.000000
# Y_pred      -0.001920  0.022329 -0.293902  0.631902 -0.788864 -0.290603
#
#                Y_pred
# PassengerId  0.011110
# Survived     0.322023
# Pclass      -0.724340
# Name        -0.046634
# Sex         -0.170000
# Age          0.224708
# SibSp       -0.001920
# Parch        0.022329
# Ticket      -0.293902
# Fare         0.631902
# Cabin       -0.788864
# Embarked    -0.290603
# Y_pred       1.000000

# %% [markdown]
# ### 6. Deployment with Streamlit:

# %% [markdown]
# ### Test Data

# %% [markdown]
# ### 1. Data Exploration

# %%
import numpy as np
import pandas as pd 
df =pd.read_csv("Titanic_test.csv")
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
numerical_col =df.select_dtypes(include =['int64','float64']).columns
numerical_col
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
categorical_col =df.select_dtypes(include =["object"]).columns
categorical_col
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
#summary statistics---> Mean ,Median, Mode,Standard deviation,Minimum,Maximum
a1 =df["Age"].mean()
a2 =df["Age"].median()
a3 =df["Age"].mode()
a4 =df["Age"].std()
a5 =df["Age"].min()
a6 =df["Age"].max()
print("Mean of the age:", a1)
print("Median of the age:",a2)
print("Mode of the age:", a3)
print("Standard deviation of the age:", a4)
print("Minimum value of the age:", a5)
print("Maximum value of the age:", a6)
# Out:
# Mean of the age: 30.272590361445783
# Median of the age: 27.0
# Mode of the age: 0    21.0
# 1    24.0
# Name: Age, dtype: float64
# Standard deviation of the age: 14.18120923562442
# Minimum value of the age: 0.17
# Maximum value of the age: 76.0

# %%
a1 =df["SibSp"].mean()
a2 =df["SibSp"].median()
a3 =df["SibSp"].mode()
a4 =df["SibSp"].std()
a5 =df["SibSp"].min()
a6 =df["SibSp"].max()
print("Mean of the SibSp:", a1)
print("Median of the SibSp:",a2)
print("Mode of the SibSp:", a3)
print("Standard deviation of the SibSp:", a4)
print("Minimum value of the SibSp:", a5)
print("Maximum value of the SibSp:", a6)
# Out:
# Mean of the SibSp: 0.4473684210526316
# Median of the SibSp: 0.0
# Mode of the SibSp: 0    0
# Name: SibSp, dtype: int64
# Standard deviation of the SibSp: 0.8967595611217125
# Minimum value of the SibSp: 0
# Maximum value of the SibSp: 8

# %%
a1 =df["Parch"].mean()
a2 =df["Parch"].median()
a3 =df["Parch"].mode()
a4 =df["Parch"].std()
a5 =df["Parch"].min()
a6 =df["Parch"].max()
print("Mean of the Parch:", a1)
print("Median of the Parch:",a2)
print("Mode of the Parch:", a3)
print("Standard deviation of the Parch:", a4)
print("Minimum value of the Parch:", a5)
print("Maximum value of the Parch:", a6)
# Out:
# Mean of the Parch: 0.3923444976076555
# Median of the Parch: 0.0
# Mode of the Parch: 0    0
# Name: Parch, dtype: int64
# Standard deviation of the Parch: 0.9814288785371684
# Minimum value of the Parch: 0
# Maximum value of the Parch: 9

# %%
a1 =df["Fare"].mean()
a2 =df["Fare"].median()
a3 =df["Fare"].mode()
a4 =df["Fare"].std()
a5 =df["Fare"].min()
a6 =df["Fare"].max()
print("Mean of the Fare:", a1)
print("Median of the Fare:",a2)
print("Mode of the Fare:", a3)
print("Standard deviation of the Fare:", a4)
print("Minimum value of the Fare:", a5)
print("Maximum value of the Fare:", a6)
# Out:
# Mean of the Fare: 35.627188489208635
# Median of the Fare: 14.4542
# Mode of the Fare: 0    7.75
# Name: Fare, dtype: float64
# Standard deviation of the Fare: 55.90757617997383
# Minimum value of the Fare: 0.0
# Maximum value of the Fare: 512.3292

# %% [markdown]
# ### Histograms

# %%
#EDA 
#histograms
import matplotlib.pyplot as plt 
print(df["Pclass"])
df["Pclass"].hist()
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64
# <Axes: >

# %%
print(df["Age"])
df["Age"].hist()
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64
# <Axes: >

# %%
print(df["SibSp"])
df["SibSp"].hist()
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    0
# 415    0
# 416    0
# 417    1
# Name: SibSp, Length: 418, dtype: int64
# <Axes: >

# %%
print(df["Parch"])
df["Parch"].hist()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    0
# 415    0
# 416    0
# 417    1
# Name: Parch, Length: 418, dtype: int64
# <Axes: >

# %%
print(df["Sex"])
df["Sex"].hist()
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object
# <Axes: >

# %%
print(df["Ticket"])
df["Ticket"].hist()
# Out:
# 0                  330911
# 1                  363272
# 2                  240276
# 3                  315154
# 4                 3101298
#               ...
# 413             A.5. 3236
# 414              PC 17758
# 415    SOTON/O.Q. 3101262
# 416                359309
# 417                  2668
# Name: Ticket, Length: 418, dtype: object
# <Axes: >

# %%
print(df["Fare"])
df["Fare"].hist()
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64
# <Axes: >

# %%
print(df["Cabin"])
df["Cabin"].hist()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 413     NaN
# 414    C105
# 415     NaN
# 416     NaN
# 417     NaN
# Name: Cabin, Length: 418, dtype: object
# <Axes: >

# %%
print(df["Embarked"])
df["Embarked"].hist()
# Out:
# 0      Q
# 1      S
# 2      Q
# 3      S
# 4      S
#       ..
# 413    S
# 414    C
# 415    S
# 416    S
# 417    C
# Name: Embarked, Length: 418, dtype: object
# <Axes: >

# %% [markdown]
# ### Boxplot

# %%
#box plots 
df.boxplot(column =["Pclass"], vert =False)
# Out:
# <Axes: >

# %%
#box plots 
df.boxplot(column =["Age"], vert =False)
# Out:
# <Axes: >

# %%
df.boxplot(column =["SibSp"], vert =False)
# Out:
# <Axes: >

# %%
df.boxplot(column =["Parch"], vert =False)
# Out:
# <Axes: >

# %%
df.boxplot(column =["Fare"], vert =False)
# Out:
# <Axes: >

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]>

# %% [markdown]
# ### 2. Data Preprocessing

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# dtype: int64

# %%
#fill missing values with Median or Mean 
df["Age"].fillna(df["Age"].median(), inplace =True)
df["Fare"].fillna(df["Fare"].median(), inplace =True)
df["Cabin"].fillna(df["Cabin"].median(), inplace =True)
# Out:
# C:\Users\banot\AppData\Local\Temp\ipykernel_20260\3402056341.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace =True)
# C:\Users\banot\AppData\Local\Temp\ipykernel_20260\3402056341.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Fare"].fillna(df["Fare"].median(), inplace =True)
# C:\Users\banot\AppData\Local\Temp\ipykernel_20260\3402056341.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Cabin"].fillna(df["Cabin"].median(), inplace =True)

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Name"] =LE.fit_transform(df["Name"])
print(df["Name"])
# Out:
# 0      108
# 1      190
# 2      353
# 3      272
# 4       15
#       ...
# 886    548
# 887    303
# 888    413
# 889     81
# 890    220
# Name: Name, Length: 891, dtype: int64

# %%
#Label Encoder
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Name"]     =LE.fit_transform(df["Name"])
df["Sex"]      =LE.fit_transform(df["Sex"])
df["Ticket"]   =LE.fit_transform(df["Ticket"])
df["Cabin"]    =LE.fit_transform(df["Cabin"])
df["Embarked"] =LE.fit_transform(df["Embarked"])

df.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            1         0       3   108    1  22.0      1      0     523
# 1            2         1       1   190    0  38.0      1      0     596
# 2            3         1       3   353    0  26.0      0      0     669
# 3            4         1       1   272    0  35.0      1      0      49
# 4            5         0       3    15    1  35.0      0      0     472
#
#       Fare  Cabin  Embarked
# 0   7.2500    147         2
# 1  71.2833     81         0
# 2   7.9250    147         2
# 3  53.1000     55         2
# 4   8.0500    147         2

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Sex"] =LE.fit_transform(df["Sex"])
print(df["Sex"])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Ticket"] =LE.fit_transform(df["Ticket"])
print(df["Ticket"])
# Out:
# 0      523
# 1      596
# 2      669
# 3       49
# 4      472
#       ...
# 886    101
# 887     14
# 888    675
# 889      8
# 890    466
# Name: Ticket, Length: 891, dtype: int64

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Cabin"] =LE.fit_transform(df["Cabin"])
print(df["Cabin"])
# Out:
# 0      147
# 1       81
# 2      147
# 3       55
# 4      147
#       ...
# 886    147
# 887     30
# 888    147
# 889     60
# 890    147
# Name: Cabin, Length: 891, dtype: int64

# %%
#DATA TRANSFORMATION
from sklearn.preprocessing import LabelEncoder 
LE =LabelEncoder()
df["Embarked"] =LE.fit_transform(df["Embarked"])
print(df["Embarked"])
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: Embarked, Length: 891, dtype: int64

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.038559  0.042939  0.034212
# Survived       -0.005007  1.000000 -0.338481 -0.057343 -0.543351 -0.064910
# Pclass         -0.035144 -0.338481  1.000000  0.052831  0.131900 -0.339898
# Name           -0.038559 -0.057343  0.052831  1.000000  0.020314  0.048252
# Sex             0.042939 -0.543351  0.131900  0.020314  1.000000  0.081163
# Age             0.034212 -0.064910 -0.339898  0.048252  0.081163  1.000000
# SibSp          -0.057527 -0.035322  0.083081 -0.017230 -0.114631 -0.233296
# Parch          -0.001652  0.081629  0.018443 -0.049105 -0.245489 -0.172482
# Ticket         -0.056554 -0.164549  0.319869  0.047348  0.059372 -0.070382
# Fare            0.012658  0.257307 -0.549500 -0.049173 -0.182333  0.096688
# Cabin          -0.035077 -0.254888  0.684121  0.061959  0.096681 -0.240839
# Embarked        0.013083 -0.163517  0.157112 -0.004557  0.104057 -0.014205
#
#                 SibSp     Parch    Ticket      Fare     Cabin  Embarked
# PassengerId -0.057527 -0.001652 -0.056554  0.012658 -0.035077  0.013083
# Survived    -0.035322  0.081629 -0.164549  0.257307 -0.254888 -0.163517
# Pclass       0.083081  0.018443  0.319869 -0.549500  0.684121  0.157112
# Name        -0.017230 -0.049105  0.047348 -0.049173  0.061959 -0.004557
# Sex         -0.114631 -0.245489  0.059372 -0.182333  0.096681  0.104057
# Age         -0.233296 -0.172482 -0.070382  0.096688 -0.240839 -0.014205
# SibSp        1.000000  0.414838  0.079461  0.159651  0.043593  0.066654
# Parch        0.414838  1.000000  0.020003  0.216225 -0.028324  0.038322
# Ticket       0.079461  0.020003  1.000000 -0.013885  0.243696 -0.006041
# Fare         0.159651  0.216225 -0.013885  1.000000 -0.503355 -0.221226
# Cabin        0.043593 -0.028324  0.243696 -0.503355  1.000000  0.193205
# Embarked     0.066654  0.038322 -0.006041 -0.221226  0.193205  1.000000

# %% [markdown]
# ### 3.Model Building

# %%
#Data partition 
Y =df["Survived"]
X =df.iloc[:, 8:]
X
# Out:
#      Ticket     Fare  Cabin  Embarked
# 0       523   7.2500    147         2
# 1       596  71.2833     81         0
# 2       669   7.9250    147         2
# 3        49  53.1000     55         2
# 4       472   8.0500    147         2
# ..      ...      ...    ...       ...
# 886     101  13.0000    147         2
# 887      14  30.0000     30         2
# 888     675  23.4500    147         2
# 889       8  30.0000     60         0
# 890     466   7.7500    147         1
#
# [891 rows x 4 columns]

# %%
from sklearn.linear_model import LogisticRegression 
model =LogisticRegression()
model.fit(X, Y)
# Out:
# LogisticRegression()

# %%
df["Y_pred"] =model.predict(X)

# %% [markdown]
# ### 4. Model Evaluation:

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score 
score =accuracy_score(Y, df["Y_pred"])
print("accuracy score:", np.round(score, 2))

ps=precision_score(Y, df["Y_pred"])
print("precision score:", np.round(ps, 2))

rs =recall_score(Y, df["Y_pred"])
print("recall score:", np.round(rs, 2))

f1s =f1_score(Y, df["Y_pred"])
print("F1 score:", np.round(f1s, 2))
# Out:
# accuracy score: 0.69
# precision score: 0.72
# recall score: 0.34
# F1 score: 0.46

# %%
from sklearn.metrics import roc_auc_score
auc =roc_auc_score(Y, df["Y_pred"])
print("Area under curve:",  np.round(auc, 3))
print("Area under curve:", (auc * 200).round(3))
# Out:
# Area under curve: 0.628
# Area under curve: 125.539

# %%
from sklearn.metrics import roc_curve 

fpr,tpr,dummy =roc_curve(Y, df["Y_pred"])

import matplotlib.pyplot as plt 
plt.scatter(x =fpr, y =tpr)
plt.plot(fpr,tpr, color ="red")
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %% [markdown]
# ### 5. Interpretation:

# %%
model.intercept_
# Out:
# array([0.82462631])

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.038559  0.042939  0.034212
# Survived       -0.005007  1.000000 -0.338481 -0.057343 -0.543351 -0.064910
# Pclass         -0.035144 -0.338481  1.000000  0.052831  0.131900 -0.339898
# Name           -0.038559 -0.057343  0.052831  1.000000  0.020314  0.048252
# Sex             0.042939 -0.543351  0.131900  0.020314  1.000000  0.081163
# Age             0.034212 -0.064910 -0.339898  0.048252  0.081163  1.000000
# SibSp          -0.057527 -0.035322  0.083081 -0.017230 -0.114631 -0.233296
# Parch          -0.001652  0.081629  0.018443 -0.049105 -0.245489 -0.172482
# Ticket         -0.056554 -0.164549  0.319869  0.047348  0.059372 -0.070382
# Fare            0.012658  0.257307 -0.549500 -0.049173 -0.182333  0.096688
# Cabin          -0.035077 -0.254888  0.684121  0.061959  0.096681 -0.240839
# Embarked        0.013083 -0.163517  0.157112 -0.004557  0.104057 -0.014205
# Y_pred          0.011110  0.322023 -0.724340 -0.046634 -0.170000  0.212521
#
#                 SibSp     Parch    Ticket      Fare     Cabin  Embarked  \
# PassengerId -0.057527 -0.001652 -0.056554  0.012658 -0.035077  0.013083
# Survived    -0.035322  0.081629 -0.164549  0.257307 -0.254888 -0.163517
# Pclass       0.083081  0.018443  0.319869 -0.549500  0.684121  0.157112
# Name        -0.017230 -0.049105  0.047348 -0.049173  0.061959 -0.004557
# Sex         -0.114631 -0.245489  0.059372 -0.182333  0.096681  0.104057
# Age         -0.233296 -0.172482 -0.070382  0.096688 -0.240839 -0.014205
# SibSp        1.000000  0.414838  0.079461  0.159651  0.043593  0.066654
# Parch        0.414838  1.000000  0.020003  0.216225 -0.028324  0.038322
# Ticket       0.079461  0.020003  1.000000 -0.013885  0.243696 -0.006041
# Fare         0.159651  0.216225 -0.013885  1.000000 -0.503355 -0.221226
# Cabin        0.043593 -0.028324  0.243696 -0.503355  1.000000  0.193205
# Embarked     0.066654  0.038322 -0.006041 -0.221226  0.193205  1.000000
# Y_pred      -0.001920  0.022329 -0.293902  0.631902 -0.788864 -0.290603
#
#                Y_pred
# PassengerId  0.011110
# Survived     0.322023
# Pclass      -0.724340
# Name        -0.046634
# Sex         -0.170000
# Age          0.212521
# SibSp       -0.001920
# Parch        0.022329
# Ticket      -0.293902
# Fare         0.631902
# Cabin       -0.788864
# Embarked    -0.290603
# Y_pred       1.000000

# %% [markdown]
# ### Interview Questions:

# %%
'''
1. What is the difference between precision and recall?

-->Sensitivity / Recall:

    From the overall Actual positiveshow much our model successfully predicted them as positives. 
    Percentage of positives that are successfully classified as positives. 
True positive Rate 
    TPR = TP/(TP + FN)
     If FN decreases Sensitivity increases, If FN increases, Sensitivity Decreases

-->Precision:

    from the model predicted positives what Percentage of people are real positives.
    The approach here is to find what percentage of the model’s positive (1’s) predictions are accurate. 
    Precision is calculated as the number of correct positive predictions (TP) divided by the total number of positive predictions 
    (TP) / (TP + FP)


2. What is cross-validation, and why is it important in binary classification?

Model is fitted on training or known data. One must do the cross-validation & model tuning before making 
any conclusions about the results. Cross-validation is done to issues like over fitting and model tuning is 
done to get the best model parameters which can give best required results. Once you have chosen the 
models, then you can perform model tuning and cross-validation for each of the chosen models. Cross
validation is like repeatedly checking the model performance on unknown dataset and thereby increasing 
the assurance of the model performance on any data set which will be fed into this model in future.

                        { OR }
Cross-validation is a statistical technique used to evaluate the performance of a machine learning model and ensure that it generalizes 
well to unseen data. It is especially important in binary classification (where there are only two class labels, e.g., "positive" and "negative") 
because it helps avoid overfitting and gives a more reliable estimate of model performance.

Cross-validation involves splitting the dataset into multiple subsets (called folds), training the model on some folds, 
and testing it on the remaining fold(s). This process is repeated several times, and the results are averaged.

Common types:
    K-Fold Cross-Validation: The dataset is divided into K equal parts. The model is trained on K-1 folds and tested on the remaining fold. 
    This process repeats K times with a different test fold each time.

    Stratified K-Fold Cross-Validation: Similar to K-Fold, but ensures each fold has the same proportion of class labels. 
    Very useful for binary classification with imbalanced data.

Why is Cross-Validation Important in Binary Classification?
    1.Reduces Overfitting Risk
    2.Gives Robust Performance Metrics
    3.Handles Class Imbalance
    4.Supports Model Selection
'''
